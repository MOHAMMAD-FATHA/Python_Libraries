# %%
"""
* @Author: Mohammad Fatha
* @Date: 2021-10-10 01:18
* @Last Modified by: Mohammad Fatha
* @Last Modified time: 2021-10-10 01:18
* @Title: :Program to draw a violin plot of sex against day for a given dataset
https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv
"""

import seaborn as sns

df_train = sns.load_dataset('tips')

sns.violinplot(x='sex',y='total_bill',hue='day',data=df_train)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>
