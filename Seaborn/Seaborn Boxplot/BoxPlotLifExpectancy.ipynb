# %%
"""
* @Author: Mohammad Fatha
* @Date: 2021-10-10 01:29
* @Last Modified by: Mohammad Fatha
* @Last Modified time: 2021-10-10 01:29
* @Title: :program to draw box plot of life expectancy by continent for a data set given in a url
https://raw.githubusercontent.com/resbaz/r-novice-gapminder-files/master/data/gapminder-FiveYearData.csv
"""

import seaborn as sns
import pandas as pd

df_train = pd.read_csv('FiveYearData.csv')

sns.boxplot(x='continent',y='lifeExp',data=df_train)
# Out:
# <AxesSubplot:xlabel='continent', ylabel='lifeExp'>
